# %%
from get_price import get_yahoo_data

# %%
df = get_yahoo_data("CLZ25.NYM")
# Out:
# 📊 Fetching 365 days of data for CLZ25.NYM...
# ✅ Retrieved 252 days
#    Range: 2024-10-01 → 2025-09-30
#    Latest: $61.96
# /Users/xikinki/Desktop/Ringshell_AI/get_price.py:41: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(

# %%
df
# Out:
#           date      close  volume
# 0   2024-10-01  67.470001  113862
# 1   2024-10-02  67.580002   55886
# 2   2024-10-03  70.010002   87165
# 3   2024-10-04  69.699997   92449
# 4   2024-10-07  71.800003   97812
# ..         ...        ...     ...
# 247 2025-09-24  64.389999  202066
# 248 2025-09-25  64.400002  163521
# 249 2025-09-26  65.139999  178625
# 250 2025-09-29  63.009998  177610
# 251 2025-09-30  61.959999  177610
#
# [252 rows x 3 columns]
